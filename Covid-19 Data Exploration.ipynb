# %% [markdown]
# # COVID-19 Data Exploration

# %% [markdown]
# This analysis of COVID-19 data examines the global deaths and vaccination rate. I intend to use this analysis to demonstrate my ability to explore, analyze, and manipulate data through SQL.

# %%
df_1 = (lambda: _deepnote_execute_sql('SELECT *\nFROM \'CovidDeaths.csv\'\nOrder By 1,2\n', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled') if '_deepnote_execute_sql' in globals() else _dntk.execute_sql('SELECT *\nFROM \'CovidDeaths.csv\'\nOrder By 1,2\n', 'SQL_DEEPNOTE_DATAFRAME_SQL', audit_sql_comment='', sql_cache_mode='cache_disabled'))()
df_1
# Out:
#       iso_code      continent  location       date  population  total_cases  \
# 0          ABW  North America     Aruba 2021-04-20    106766.0          NaN
# 1          ABW  North America     Aruba 2021-04-12    106766.0          NaN
# 2          ABW  North America     Aruba 2021-04-11    106766.0          NaN
# 3          ABW  North America     Aruba 2021-04-10    106766.0          NaN
# 4          ABW  North America     Aruba 2021-04-09    106766.0          NaN
# ...        ...            ...       ...        ...         ...          ...
# 85166      ZWE         Africa  Zimbabwe 2021-04-26  14862927.0      38102.0
# 85167      ZWE         Africa  Zimbabwe 2021-04-27  14862927.0      38164.0
# 85168      ZWE         Africa  Zimbabwe 2020-03-20  14862927.0          1.0
# 85169      ZWE         Africa  Zimbabwe 2021-04-30  14862927.0      38257.0
# 85170      ZWE         Africa  Zimbabwe 2020-06-30  14862927.0        591.0
#
# ...

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=b974c2c1-fe68-46ce-84d4-301eca69d5cf' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
